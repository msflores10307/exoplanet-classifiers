# %%
import pandas as pd

# %%
rawData = pd.read_csv('exoplanets.csv')
rawData
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# ...

# %%
rawData.columns
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
dataTypes = pd.DataFrame(rawData.dtypes).reset_index().rename(columns={'index':'Field',0:'type'})
numericalFields = dataTypes.loc[dataTypes['type']=='float64']
numericalFields.to_csv('numericalFields.csv')
binaryFields = dataTypes.loc[dataTypes['type']=='int64']

stringFields = dataTypes.loc[dataTypes['type']=='object']
# Out:
#                 Field     type
# 6           koi_score  float64
# 11         koi_period  float64
# 12    koi_period_err1  float64
# 13    koi_period_err2  float64
# 14        koi_time0bk  float64
# 15   koi_time0bk_err1  float64
# 16   koi_time0bk_err2  float64
# 17         koi_impact  float64
# 18    koi_impact_err1  float64
# 19    koi_impact_err2  float64
# 20       koi_duration  float64
# 21  koi_duration_err1  float64
# 22  koi_duration_err2  float64
# 23          koi_depth  float64
# 24     koi_depth_err1  float64
# 25     koi_depth_err2  float64
# 26           koi_prad  float64
# 27      koi_prad_err1  float64
# 28      koi_prad_err2  float64
# 29            koi_teq  float64
# 30       koi_teq_err1  float64
# 31       koi_teq_err2  float64
# 32          koi_insol  float64
# 33     koi_insol_err1  float64
# 34     koi_insol_err2  float64
# 35      koi_model_snr  float64
# 36   koi_tce_plnt_num  float64
# 38          koi_steff  float64
# 39     koi_steff_err1  float64
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
numericalFields
test_df = pd.DataFrame([])
test_df['nConfirmed'] = rawData['koi_score'].loc[rawData.koi_disposition == 'CONFIRMED']
nFalsePos = rawData['koi_score'].loc[rawData.koi_disposition == 'FALSE POSITIVE']
test_df['nCandidate'] = rawData['koi_score'].loc[rawData.koi_disposition == 'CANDIDATE']
nCandidate = pd.DataFrame(rawData['koi_score'].loc[rawData.koi_disposition == 'CANDIDATE'])
# nCandidate.describe()
# um = [nConfirmed[''], nFalsePos, nCandidate]
# um

# %%
oxplot = rawData[['koi_disposition','koi_score']].boxplot(by='koi_disposition')

# %%
import matplotlib as plt
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
for row in numericalFields.iterrows():
    field = row[1]['Field']
    boxplot = rawData[['koi_disposition',f'{field}']].boxplot(by='koi_disposition')

# %%
fieldList = []
for row in numericalFields.iterrows():
    fieldList.append(row[1]['Field'])
print(fieldList)
# Out:
# ['koi_score', 'koi_period', 'koi_period_err1', 'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2', 'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
transform = rawData 
transform.head()
transform[fieldList] = pd.DataFrame(scaler.fit_transform(rawData[fieldList]))
transform.head()
# Out:
# C:\Users\msflo\anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py:375: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\msflo\anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py:376: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# ...

# %%
for row in numericalFields.iterrows():
    field = row[1]['Field']
    boxplot = transform[['koi_disposition',f'{field}']].boxplot(by='koi_disposition')

# %%
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
standardTransform = rawData 
standardTransform[fieldList] = pd.DataFrame(standardScaler.fit_transform(rawData[fieldList]))
transform.head()
# Out:
# C:\Users\msflo\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\extmath.py:765: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\msflo\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\extmath.py:706: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = op(x, *args, **kwargs)
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# ...

# %%
for row in numericalFields.iterrows():
    field = row[1]['Field']
    boxplot = standardTransform[['koi_disposition',f'{field}']].boxplot(by='koi_disposition')

# %%
# testing colinearity, take koi_period_err1
from scipy import stats
transform.plot.scatter(x='koi_period_err1', y = 'koi_period_err2')
slope,b,r, p,e = stats.linregress(transform['koi_period_err1'].dropna(),transform['koi_period_err2'].dropna())
print(f"R-squared: {r**2}")
# Out:
# R-squared: 1.0

# %%
# testing colinearity, take koi_impact
transform.plot.scatter(x='koi_impact', y = 'koi_impact_err1')

# %%
# testing colinearity, take both.

transform.plot.scatter(x='koi_impact', y = 'koi_impact_err2')

# %%
# testing colinearity, take both.

transform.plot.scatter(x='koi_duration', y = 'koi_duration_err2')
